# %% [markdown]
# <a href="https://colab.research.google.com/github/HamburgermanA3445/heartdiseaseprediction/blob/main/MLProjectFigures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#predicting heart disease as target with all featuers
#dataset 6: log 84% neural 80% Tensor 77% rf 90% dt 88% knn 73% gbm 89% svm 85% et 91%
#below is extra trees' feature importance
"""           Feature  Importance
10        ST_Slope    0.205436
8   ExerciseAngina    0.161701
9          Oldpeak    0.096421
4      Cholesterol    0.092057
2    ChestPainType    0.090106
7            MaxHR    0.082874
0              Age    0.074509
3        RestingBP    0.064317
1              Sex    0.054630
5        FastingBS    0.040683
6       RestingECG    0.037265"""
#dataset 3: log 83% neural 84% Tensor 82% Rf 89% dt 87% knn 74% gbm 92% svm 86% et 94%
#et below importance
"""                Feature  Importance
10             ST slope    0.161499
8       exercise angina    0.140620
2       chest pain type    0.129899
9               oldpeak    0.095566
7        max heart rate    0.093239
4           cholesterol    0.089776
0                   age    0.080637
3          resting bp s    0.075222
1                   sex    0.055412
6           resting ecg    0.041936
5   fasting blood sugar    0.036194"""
#dataset 2: log 79% neural 82% tensor 92% rf 85% dt 85% knn 73% gbm 93% svm 82% et 100%
#et feature importance
"""     Feature  Importance
2         cp    0.119356
11        ca    0.118884
12      thal    0.110466
8      exang    0.099474
9    oldpeak    0.097429
7    thalach    0.081728
10     slope    0.073975
0        age    0.072687
3   trestbps    0.061187
4       chol    0.061075
1        sex    0.052402
6    restecg    0.031949
5        fbs    0.019388"""

# %%
import matplotlib.pyplot as plt

features = ['ST_Slope', 'ExerciseAngina', 'Oldpeak', 'Cholesterol', 'ChestPainType', 'MaxHR', 'Age', 'RestingBP', 'Sex', 'FastingBS', 'RestingECG']
importances = [0.205436, 0.161701, 0.096421, 0.092057, 0.090106, 0.082874, 0.074509, 0.064317, 0.054630, 0.040683, 0.037265]

plt.figure(figsize=(10, 6))
bars = plt.barh(features, importances, color='skyblue', edgecolor='black')
plt.xlabel('Importance', fontsize=12)
plt.ylabel('Feature', fontsize=12)
"""plt.title('Dataset 6: Extra Trees Feature Importance')"""
plt.gca().invert_yaxis()

for bar in bars:
    plt.text(bar.get_width() - 0.005, bar.get_y() + bar.get_height()/2, f'{bar.get_width():.3f}', va='center', ha='right')

plt.show()

# %%
import matplotlib.pyplot as plt

features = ['ST slope', 'exercise angina', 'chest pain type', 'oldpeak', 'max heart rate', 'cholesterol', 'age', 'resting bp s', 'sex', 'resting ecg', 'fasting blood sugar']
importances = [0.161499, 0.140620, 0.129899, 0.095566, 0.093239, 0.089776, 0.080637, 0.075222, 0.055412, 0.041936, 0.036194]

plt.figure(figsize=(10, 6))
bars = plt.barh(features, importances, color='skyblue', edgecolor='black')
plt.xlabel('Importance', fontsize=12)
plt.ylabel('Feature', fontsize=12)
#d3fl
plt.gca().invert_yaxis()

for bar in bars:
    plt.text(bar.get_width() - 0.005, bar.get_y() + bar.get_height()/2, f'{bar.get_width():.3f}', va='center', ha='right')

plt.show()

# %%
import matplotlib.pyplot as plt

features = ['cp', 'ca', 'thal', 'exang', 'oldpeak', 'thalach', 'slope', 'age', 'trestbps', 'chol', 'sex', 'restecg', 'fbs']
importances = [0.119356, 0.118884, 0.110466, 0.099474, 0.097429, 0.081728, 0.073975, 0.072687, 0.061187, 0.061075, 0.052402, 0.031949, 0.019388]

plt.figure(figsize=(10, 6))
bars = plt.barh(features, importances, color='skyblue', edgecolor='black')
plt.xlabel('Importance', fontsize=12)
plt.ylabel('Feature', fontsize=12)
plt.gca().invert_yaxis()
#d2fl
for bar in bars:
    plt.text(bar.get_width() - 0.005, bar.get_y() + bar.get_height()/2, f'{bar.get_width():.3f}', va='center', ha='right')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['Logistic Regression', 'Neural Network', 'TensorFlow', 'Random Forest', 'Decision Tree', 'K-Nearest Neighbors', 'Gradient Boosting', 'SVM', 'Extra Trees']
accuracies = [84, 80, 77, 90, 88, 73, 89, 85, 91]

plt.figure(figsize=(12, 6))
bars = plt.bar(models, accuracies, color='lightgreen', edgecolor='black', linewidth=1.2)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 5, f'{yval}%', ha='center', va='bottom', fontsize=12)

plt.xticks(rotation=45, ha='right')
plt.ylabel('Accuracy (%)', fontsize=12)
"""plt.title('Model Accuracies for Dataset 6')"""

plt.ylim(0, 120)

current_ticks = plt.yticks()[0]
new_ticks = [tick for tick in current_ticks if tick < 120]
plt.yticks(new_ticks)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['Logistic Regression', 'Neural Network', 'TensorFlow', 'Random Forest', 'Decision Tree', 'K-Nearest Neighbors', 'Gradient Boosting', 'SVM', 'Extra Trees']
accuracies = [83, 84, 82, 89, 87, 74, 92, 86, 94]

plt.figure(figsize=(12, 6))
bars = plt.bar(models, accuracies, color='lightgreen', edgecolor='black', linewidth=1.2)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 5, f'{yval}%', ha='center', va='bottom', fontsize=12)

plt.xticks(rotation=45, ha='right')
plt.ylabel('Accuracy (%)', fontsize=12)
"""plt.title('Model Accuracies for Dataset 3')"""

plt.ylim(0, 120)

current_ticks = plt.yticks()[0]
new_ticks = [tick for tick in current_ticks if tick < 120]
plt.yticks(new_ticks)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['Logistic Regression', 'Neural Network', 'TensorFlow', 'Random Forest', 'Decision Tree', 'K-Nearest Neighbors', 'Gradient Boosting', 'SVM', 'Extra Trees']
accuracies = [79, 82, 92, 85, 85, 73, 93, 82, 100]

plt.figure(figsize=(12, 6))
bars = plt.bar(models, accuracies, color='lightgreen', edgecolor='black', linewidth=1.2)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 5, f'{yval}%', ha='center', va='bottom', fontsize=12)

plt.xticks(rotation=45, ha='right')
plt.ylabel('Accuracy (%)', fontsize=12)
"""plt.title('Model Accuracies for Dataset 2')"""

plt.ylim(0, 120)

current_ticks = plt.yticks()[0]
new_ticks = [tick for tick in current_ticks if tick < 120]
plt.yticks(new_ticks)

plt.show()
